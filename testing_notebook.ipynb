# %%
from cluster import myKMeans
from cluster import mySilhouette
from cluster import make_clusters, plot_clusters, plot_multipanel
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Using Utility Function for Visualization

# %%
# here we are making tightly clustered data by lowering the scale param
t_clusters, t_labels = make_clusters(scale=0.3) 
#plot_clusters(t_clusters, t_labels)
#plt.show()
t_clusters.shape, t_labels.shape
# Out:
# ((500, 2), (500,))

# %%
# show a multipanel visualization of clusters with true labels, predicted labels, and silhouette scores
# you will need to calculate these predicted labels with your kmeans implementation and the scores 
# with your silhouette score implementation

# YOUR CODE HERE
pred_labels = myKMeans(3)
pred_labels.fit(t_clusters)
pred_labels = pred_labels.predict(t_clusters)
pred_labels.shape
# Out:
# (500,)

# %%
silhouette = mySilhouette()
scores = silhouette.score(t_clusters, pred_labels)

# %%
"""
Cluster Generation
"""

# here we are making tightly clustered data by lowering the scale param
t_clusters, t_labels = make_clusters(scale=0.3) 

# here we are making loosely clustered data by increasing the scale param
l_clusters, l_labels = make_clusters(scale=2) 

# here we are making many clusters by adjusting the `k` param
m_clusters, m_labels = make_clusters(k=10)

# here we are directly controlling the dimensionality of our data 
#   1000 observations 
#   200 features 
#   3 clusters)
d_clusters, d_labels = make_clusters(n=1000, m=200, k=3)

# %%
"""
Cluster Visualization
"""
# show the visualization for some clusters and their associated labels
#plot_clusters(t_clusters, t_labels)
# Out:
# '\nCluster Visualization\n'

# %%
# show a multipanel visualization of clusters with true labels, predicted labels, and silhouette scores
# you will need to calculate these predicted labels with your kmeans implementation and the scores 
# with your silhouette score implementation

# YOUR CODE HERE
#
pred_labels = myKMeans(3)
pred_labels.fit(t_clusters)
pred_labels = pred_labels.predict(t_clusters)

silhouette = mySilhouette()
scores = silhouette.score(t_clusters, pred_labels)



plot_multipanel(t_clusters, t_labels, pred_labels, scores)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# YOUR CODE HERE
#
pred_labels = myKMeans(3)
pred_labels.fit(l_clusters)
pred_labels = pred_labels.predict(l_clusters)

silhouette = mySilhouette()
scores = silhouette.score(l_clusters, pred_labels)



plot_multipanel(l_clusters, l_labels, pred_labels, scores)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# YOUR CODE HERE
#
pred_labels = myKMeans(3)
pred_labels.fit(m_clusters)
pred_labels = pred_labels.predict(m_clusters)

silhouette = mySilhouette()
scores = silhouette.score(m_clusters, pred_labels)



plot_multipanel(m_clusters, m_labels, pred_labels, scores)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# YOUR CODE HERE
#
pred_labels = myKMeans(3)
pred_labels.fit(d_clusters)
pred_labels = pred_labels.predict(d_clusters)

silhouette = mySilhouette()
scores = silhouette.score(d_clusters, pred_labels)

plot_multipanel(d_clusters, d_labels, pred_labels, scores)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
